# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Clean_Dataset.csv")
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# 1             Morning           Mumbai   Economy      2.33          1   5953
# 2       Early_Morning           Mumbai   Economy      2.17          1   5956
# 3           Afternoon           Mumbai   Economy      2.25          1   5955
# 4             Morning           Mumbai   Economy      2.33          1   5955
# ...               ...              ...       ...       ...        ...    ...
# 300148        Evening        Hyderabad  Business     10.08         49  69265
# 300149          Night        Hyderabad  Business     10.42         49  77105
# 300150          Night        Hyderabad  Business     13.83         49  79099
# 300151        Evening        Hyderabad  Business     10.00         49  81585
# 300152        Evening        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 12 columns]

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
df.tail()
# Out:
#         Unnamed: 0  airline  flight source_city departure_time stops  \
# 300148      300148  Vistara  UK-822     Chennai        Morning   one
# 300149      300149  Vistara  UK-826     Chennai      Afternoon   one
# 300150      300150  Vistara  UK-832     Chennai  Early_Morning   one
# 300151      300151  Vistara  UK-828     Chennai  Early_Morning   one
# 300152      300152  Vistara  UK-822     Chennai        Morning   one
#
#        arrival_time destination_city     class  duration  days_left  price
# 300148      Evening        Hyderabad  Business     10.08         49  69265
# 300149        Night        Hyderabad  Business     10.42         49  77105
# 300150        Night        Hyderabad  Business     13.83         49  79099
# 300151      Evening        Hyderabad  Business     10.00         49  81585
# 300152      Evening        Hyderabad  Business     10.08         49  81585

# %% [markdown]
# (take random sample from dataset)

# %%
df.sample(10)
# Out:
#         Unnamed: 0    airline   flight source_city departure_time  \
# 125660      125660    AirAsia   I5-582     Kolkata        Morning
# 52343        52343    Vistara   UK-875      Mumbai        Evening
# 122418      122418    AirAsia  I5-1563     Kolkata        Evening
# 94659        94659   GO_FIRST   G8-801   Bangalore  Early_Morning
# 223915      223915    Vistara   UK-985       Delhi        Evening
# 117091      117091  Air_India   AI-808   Bangalore          Night
# 190417      190417     Indigo  6E-6006     Chennai      Afternoon
# 59036        59036    Vistara   UK-875      Mumbai        Evening
# 170206      170206    Vistara   UK-860   Hyderabad  Early_Morning
# 42121        42121     Indigo  6E-6238       Delhi        Morning
#
#               stops arrival_time destination_city     class  duration  \
# 125660          one    Afternoon            Delhi   Economy      5.83
# 52343           one    Afternoon            Delhi   Economy     17.17
# 122418  two_or_more    Afternoon            Delhi   Economy     18.33
# 94659           one        Night           Mumbai   Economy     14.75
# 223915          one      Morning          Chennai  Business     16.00
# 117091          one      Morning          Chennai   Economy     11.92
# 190417          one        Night           Mumbai   Economy      5.00
# 59036           one      Morning        Bangalore   Economy     13.50
# 170206          one      Evening        Bangalore   Economy     11.83
# 42121          zero      Morning          Chennai   Economy      2.83
#
#         days_left  price
# 125660         39   3014
# 52343          47   5232
# 122418         20   3014
# 94659           5  13184
# 223915         33  65832
# 117091         20   7704
# 190417         24   4476
# 59036          36   4658
# 170206         45   6461
# 42121          44   2823

# %%
df.shape
# Out:
# (300153, 12)

# %% [markdown]
# # information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# to drop row or column or multiple rows or columns

# %%
df.drop('Unnamed: 0',axis = 1 , inplace = True)

# %% [markdown]
# to know total number of unique values in each column in our dataframe

# %%
df.nunique()
# Out:
# airline                 6
# flight               1561
# source_city             6
# departure_time          6
# stops                   3
# arrival_time            6
# destination_city        6
# class                   2
# duration              476
# days_left              49
# price               12157
# dtype: int64

# %%
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# to know statistical description for Numerical columns

# %%
df.describe().T
# Out:
#               count          mean           std      min      25%      50%  \
# duration   300153.0     12.221021      7.191997     0.83     6.83    11.25
# days_left  300153.0     26.004751     13.561004     1.00    15.00    26.00
# price      300153.0  20889.660523  22697.767366  1105.00  4783.00  7425.00
#
#                 75%        max
# duration      16.17      49.83
# days_left     38.00      49.00
# price      42521.00  123071.00

# %%
df.describe(include = 'O').T
# Out:
#                    count unique      top    freq
# airline           300153      6  Vistara  127859
# flight            300153   1561   UK-706    3235
# source_city       300153      6    Delhi   61343
# departure_time    300153      6  Morning   71146
# stops             300153      3      one  250863
# arrival_time      300153      6    Night   91538
# destination_city  300153      6   Mumbai   59097
# class             300153      2  Economy  206666

# %%
df.describe(include = 'all').T
# Out:
#                      count unique      top    freq          mean  \
# airline             300153      6  Vistara  127859           NaN
# flight              300153   1561   UK-706    3235           NaN
# source_city         300153      6    Delhi   61343           NaN
# departure_time      300153      6  Morning   71146           NaN
# stops               300153      3      one  250863           NaN
# arrival_time        300153      6    Night   91538           NaN
# destination_city    300153      6   Mumbai   59097           NaN
# class               300153      2  Economy  206666           NaN
# duration          300153.0    NaN      NaN     NaN     12.221021
# days_left         300153.0    NaN      NaN     NaN     26.004751
# price             300153.0    NaN      NaN     NaN  20889.660523
#
#                            std     min     25%     50%      75%       max
# airline                    NaN     NaN     NaN     NaN      NaN       NaN
# flight                     NaN     NaN     NaN     NaN      NaN       NaN
# source_city                NaN     NaN     NaN     NaN      NaN       NaN
# departure_time             NaN     NaN     NaN     NaN      NaN       NaN
# stops                      NaN     NaN     NaN     NaN      NaN       NaN
# arrival_time               NaN     NaN     NaN     NaN      NaN       NaN
# destination_city           NaN     NaN     NaN     NaN      NaN       NaN
# class                      NaN     NaN     NaN     NaN      NaN       NaN
# duration              7.191997    0.83    6.83   11.25    16.17     49.83
# days_left            13.561004     1.0    15.0    26.0     38.0      49.0
# price             22697.767366  1105.0  4783.0  7425.0  42521.0  123071.0

# %% [markdown]
# # Check Distributions for Numerical Columns

# %%
plt.figure(figsize = (10,6))
sns.histplot(data=df, x="duration" , kde = 'dist')
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Count'>

# %% [markdown]
# Note: number of passengers decrease when duration of flight increase

# %%
plt.figure(figsize = (10,6))
sns.histplot(data=df, x="days_left")
# Out:
# <AxesSubplot:xlabel='days_left', ylabel='Count'>

# %% [markdown]
# Note: most of passengers book the tickets before thier flight trip interval between [50,10] days

# %%
plt.figure(figsize = (10,6))
sns.displot(data=df, x="price" , kde = 'hist')

# %% [markdown]
#  Note: we have a passengers thier tickets more than 20000 so we want to know what the class they are belong and thier airline

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(21,7))
sns.boxplot(data=df, y="duration" , color ='#FF8000' , ax = ax1)
sns.boxplot(data=df, y="days_left" , color ='#FF3333', ax = ax2)
sns.boxplot(data=df, y="price" , color ='#009900', ax = ax3)
for ax in plt.gcf().axes:
    l = ax.get_ylabel()
    ax.set_ylabel(l, fontsize=15)
plt.show()

# %% [markdown]
#  Note: we notice we have outliers in duration and price columns

# %% [markdown]
# # Questions

# %% [markdown]
# # 1.what is the ratio between Bussiness and Economy?

# %%
round((df['class'].value_counts()/df.shape[0])*100,1)
# Out:
# Economy     68.9
# Business    31.1
# Name: class, dtype: float64

# %%
colors = sns.color_palette("ch:start=.2,rot=-.3")[0:5]
plt.figure (figsize=(10,7))
plt.pie(round((df['class'].value_counts()/df.shape[0])*100,1), labels = df['class'].unique(), colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# Note: most of passengers that books ticket are Economy Class

# %% [markdown]
# # 2.which class that i get more profit from it?

# %%
sns.set(style="whitegrid")
sns.displot(data=df, x="price", hue="class" , kind = "hist")

# %% [markdown]
# Note: that tickets with high price Bussiness passengers book it so profit comes from bussiness greater than Economy

# %% [markdown]
# # 3.what is the ratio between different airlines?

# %%
df1 = round((df['airline'].value_counts()/df.shape[0])*100,1)
df1
# Out:
# Vistara      42.6
# Air_India    27.0
# Indigo       14.4
# GO_FIRST      7.7
# AirAsia       5.4
# SpiceJet      3.0
# Name: airline, dtype: float64

# %%
colors = sns.color_palette("Spectral")[0:25]
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.figure (figsize=(10,7))
plt.pie(df1, labels =df1.index, colors = colors, autopct='%.0f%%')
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# Note: the top 2 airlines are Vistara and air-india and least airline is Spicejet

# %% [markdown]
# # 4.What is the heighest price according to departuretime?

# %%
sns.barplot(x='departure_time',y ='price',data=df,palette='Blues_d')
# Out:
# <AxesSubplot:xlabel='departure_time', ylabel='price'>

# %% [markdown]
#  Note: It seems that the heighest price is Night time.

# %% [markdown]
# # 5. Is the ticket price affected by the number of stops between source and destination cities ?

# %%
df.groupby('stops')['price'].mean()
# Out:
# stops
# one            22900.992482
# two_or_more    14113.450775
# zero            9375.938535
# Name: price, dtype: float64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='stops', y='price', data=df)
plt.xlabel('Number of Stops')
plt.ylabel('Average Price')
plt.title('number of stops VS Ticket price')
plt.show()

# %% [markdown]
# Note:from the above graph and the result before , we get that for zero stops , the flights price is cheaper than if there is two or more stops , and it's more expensive for one-stop flights.

# %% [markdown]
# # 6. Which airline is most used?

# %%
df['airline'].value_counts()
# Out:
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: airline, dtype: int64

# %%
airline_counts = df['airline'].value_counts()
sizes = airline_counts.values
labels = airline_counts.index
plt.pie(x=sizes,labels=labels,autopct='%1.1f%%',startangle=60)
plt.axis('equal')
plt.show()

# %% [markdown]
# According to above pie, we see that Vistara airline is most used by 42.6%

# %% [markdown]
# # 7.From which city do most flights depart?

# %%
src_city_cnts = df.source_city.value_counts()
src_city_cnts = pd.DataFrame(src_city_cnts).reset_index()
src_city_cnts.columns = ['city','count']
src_city_cnts
# Out:
#         city  count
# 0      Delhi  61343
# 1     Mumbai  60896
# 2  Bangalore  52061
# 3    Kolkata  46347
# 4  Hyderabad  40806
# 5    Chennai  38700

# %%
plt.figure(figsize=(9,6))
fig = sns.barplot(x='city',y='count',data=src_city_cnts,palette='Set2')
plt.show(fig)
plt.close('all')
del fig

# %% [markdown]
# Most of the flights originate from either Delhi or Mumbai.

# %% [markdown]
# # 8.How is the price affected when tickets are bought in just 1 or 2 days before departure?

# %%
df_temp = df.groupby(['days_left'])['price'].mean().reset_index()

plt.figure(figsize=(15,6))
ax = sns.lineplot(x="days_left", y="price", data=df_temp).set_title("Average prices depending on the days left",fontsize=15)

# %% [markdown]
# as we can see here the price is very expensive when registration is in 2 days before the trip

# %% [markdown]
# # 9.Does price vary with Airlines?

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x='airline', y='price', data=df, palette='hls')
plt.title('Airlines Vs Average Price', fontsize=15)
plt.xlabel('Airline', fontsize=15)
plt.ylabel('Average Price', fontsize=15)
plt.xticks(rotation=45)  
plt.show()

# %%
plt.figure(figsize=(15, 5))
df['price'].plot()
plt.xlabel('airline')
plt.ylabel('price')
plt.title(' Amount over Time')
plt.show()

# %% [markdown]
# Vistara and Air_India Airlines Have Maximum Price when compared to Others so yes the price vary with Airlines.

# %%
df.corr()['price']
# Out:
# duration     0.204222
# days_left   -0.091949
# price        1.000000
# Name: price, dtype: float64

# %%
sns.heatmap(df.iloc[:,2:12].corr(), annot = True)
plt.title ("Visualizing correlation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 10. what are the peak hours for Departure?

# %%
sns.displot(x=df['departure_time'], data=df, kde=True).fig.set_figwidth(10)

# %% [markdown]
# Most flights' departure time: Morning

# %% [markdown]
# # 11.Is the price affected by destinationcity?

# %%
df['destination_city'].value_counts()
# Out:
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: destination_city, dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.barplot(x='destination_city',y='price',data=df.sort_values('price',ascending=False),palette=sns.cubehelix_palette(8))
# Out:
# <AxesSubplot:xlabel='destination_city', ylabel='price'>

# %% [markdown]
# KolKata is the most price range becuase its Distance from Source City or to Distination City .

# %%
from sklearn.preprocessing import LabelEncoder
categorial_data=df.select_dtypes(include='object').columns

# %%
for column in categorial_data:
    l_encoder = LabelEncoder()
    df[column] = l_encoder.fit_transform(df[column])

# %%
for column in categorial_data:
    l_encoder = LabelEncoder()
    df[column] = l_encoder.fit_transform(df[column])

# %%
df=df.drop("flight",axis=1)

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(df.corr() ,annot=True, cmap='RdBu_r')
plt.show()

# %%
x=df.drop("price",axis=1).values

# %%
y=df["price"].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.2, random_state = 24)

# %%
print('length of training set', len(X_train))
print('length of testing set', len(X_test))
# Out:
# length of training set 240122
# length of testing set 60031

# %%
ln=LinearRegression()
ln.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
ln.intercept_
# Out:
# 50600.416151544305

# %%
ln.coef_
# Out:
# array([ 9.54917154e+02,  1.02690569e+02,  3.48363946e+01, -3.26871287e+03,
#         1.89577997e+02,  1.17481905e+02, -4.45569132e+04,  9.11228796e+01,
#        -1.31399411e+02])

# %%
df1 = pd.DataFrame(ln.coef_ , df.columns[:-1] , columns=['coeficient'])
df1.sort_values("coeficient" ,  ascending= False)
# Out:
#                     coeficient
# airline             954.917154
# arrival_time        189.577997
# destination_city    117.481905
# source_city         102.690569
# duration             91.122880
# departure_time       34.836395
# days_left          -131.399411
# stops             -3268.712869
# class            -44556.913225

# %%
ln.score(X_train,Y_train)
# Out:
# 0.9045582489744145

# %%
y_pred=ln.predict(X_test)

# %%
df_prediction=pd.DataFrame({"y_test":Y_test,"y_pred":y_pred})
df_prediction.head(30)
# Out:
#     y_test        y_pred
# 0     4020   5602.197076
# 1     4755   7063.844846
# 2     5206   7406.421101
# 3    60260  57481.343786
# 4     6172  10371.973985
# 5     6502   6639.330772
# 6    80861  53173.124344
# 7     7221   8607.204921
# 8     6287  11015.861405
# 9    49553  50559.892844
# 10    4672   4318.718027
# 11   15663  11833.527711
# 12    3961   1088.054584
# 13    8111   7982.893466
# 14    5352   9008.220200
# 15    3436   5103.132733
# 16   62591  57823.723216
# 17    6502   4314.417910
# 18    5102   3708.704819
# 19    7413   6294.361995
# 20   49725  48557.769432
# 21    6287   8312.978924
# 22   10897   7817.744072
# 23   13938  12575.389427
# 24    2409   5530.960162
# 25    2074    277.832606
# 26    6296   8420.689271
# 27    5233   5497.468166
# 28    6454   3915.186283
# 29    4020   3837.661916

# %%
df_prediction.shape
# Out:
# (60031, 2)

# %%
plt.Figure(figsize=(20,8))
plt.plot(df_prediction[:50])
plt.legend(["actul","prediction"])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,mean_absolute_percentage_error

# %%
score = ln.score(X_test, Y_test)
mse = mean_squared_error(Y_test, y_pred)
r2_score = r2_score(Y_test, y_pred)


print("Accuracy of Model: ",score)
print("MSE: ",mse)
print("R-Squared: ",r2_score)
# Out:
# Accuracy of Model:  0.9048083211033208
# MSE:  49008520.64943928
# R-Squared:  0.9048083211033208

# %%
import statsmodels.api as sm
from scipy import stats

# %%
x2 = sm.add_constant(X_train)
est = sm.OLS(Y_train , x2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                 2.529e+05
# Date:                Sat, 15 Jun 2024   Prob (F-statistic):               0.00
# Time:                        12:52:27   Log-Likelihood:            -2.4671e+06
# No. Observations:              240122   AIC:                         4.934e+06
# Df Residuals:                  240112   BIC:                         4.934e+06
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        5.06e+04     75.348    671.560      0.000    5.05e+04    5.07e+04
# x1           954.9172      7.966    119.875      0.000     939.304     970.530
# x2           102.6906      8.387     12.243      0.000      86.251     119.130
# x3            34.8364      8.229      4.233      0.000      18.708      50.965
# x4         -3268.7129     24.491   -133.468      0.000   -3316.714   -3220.712
# x5           189.5780      8.247     22.988      0.000     173.414     205.742
# x6           117.4819      8.433     13.932      0.000     100.954     134.010
# x7         -4.456e+04     31.781  -1402.020      0.000   -4.46e+04   -4.45e+04
# x8            91.1229      2.286     39.859      0.000      86.642      95.604
# x9          -131.3994      1.057   -124.350      0.000    -133.471    -129.328
# ==============================================================================
# Omnibus:                    32219.864   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           288253.150
# Skew:                           0.351   Prob(JB):                         0.00
# Kurtosis:                       8.321   Cond. No.                         172.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

dt = DecisionTreeRegressor(random_state=42)

# %%
dt.fit(X_train, Y_train)


y_pred_train = dt.predict(X_train)
y_pred_test = dt.predict(X_test)

# %%
accuracy_train = dt.score(X_train, Y_train)
mse_train = mean_squared_error(Y_train, y_pred_train)
r2_train = r2_score(Y_train, y_pred_train)


accuracy_test = dt.score(X_test, Y_test)
mse_test = mean_squared_error(Y_test, y_pred_test)
r2_test = r2_score(Y_test, y_pred_test)

print("Accuracy - Train: {:} Test: {:}".format(accuracy_train, accuracy_test))
print("MSE - Train: {:} Test: {:}".format(mse_train, mse_test))
print("R2 - Train: {:} Test: {:}".format(r2_train, r2_test))
# Out:
# Accuracy - Train: 0.9992933870196173 Test: 0.9760139910025779
# MSE - Train: 364098.9103525153 Test: 12348966.116289454
# R2 - Train: 0.9992933870196173 Test: 0.9760139910025779

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

rf = RandomForestRegressor(n_estimators=10, random_state=52)

rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=52)

# %%
y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)

accuracy_train = rf.score(X_train, Y_train)
mse_train = mean_squared_error(Y_train, y_pred_train)
r2_train = r2_score(Y_train, y_pred_train)

# %%
accuracy_test = rf.score(X_test, Y_test)
mse_test = mean_squared_error(Y_test, y_pred_test)
r2_test = r2_score(Y_test, y_pred_test)

print("Accuracy - Train: {:} Test: {:}".format(accuracy_train, accuracy_test))
print("MSE - Train: {:} Test: {:}".format(mse_train, mse_test))
print("R2 - Train: {:} Test: {:}".format(r2_train, r2_test))
# Out:
# Accuracy - Train: 0.9967943129931921 Test: 0.9840990880487787
# MSE - Train: 1651805.4133083343 Test: 8186431.637078019
# R2 - Train: 0.9967943129931921 Test: 0.9840990880487787
